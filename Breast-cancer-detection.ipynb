# %% [markdown]
# # AWS SageMaker Linear-Learner Algorithm for Breast Cancer Prediction

# %%
$AWS SageMaker is a fully managed AWS service to build, train and deploy Machine Learning(ML) models. 
$It has three services namely Notebook Instances, Training Instances and Endpoint Instances.
$The Notebook Instances can host Jupiter notebooks to perform exploratory data analysis by accessing 
raw data from Amazon s3 buckets and stores the training data again in s3. 
$The Training Instances train the ML models on the training data by choosing any of the instances based on the data and model 
requirements. The trained models are in turn send to s3 for future use. 
$The trained models are deployed to the endpoints by Endpoint Instances for making predictions on the unseen data.

AWS SageMaker has many inbuilt ML algorithms and Linear-Learner is one amongst them. 
It is a supervised learning algorithm to solve either Regression or Classification problems. 
I will be using Linear-Learner algorithm for classifying whether a patient has breast cancer or not.

The idea is here is to explore and understand the capabilities and functionality of AWS SageMaker for data exploratory , 
training and deployment processes.

# %% [markdown]
# # Data sources:
#
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Original)

# %%
import sagemaker
from sagemaker.session import Session
from sagemaker import get_execution_role
from sagemaker import LinearLearner
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import boto3
from sagemaker import get_execution_role

# Get the SageMaker execution role
role = get_execution_role()

# Specify the S3 bucket and file path
bucket = 'sagemaker-17'
data_key = 'cancer-dir/data.csv'
data_location = f's3://{bucket}/{data_key}'

# Read the CSV file from S3 into a DataFrame
df = pd.read_csv(data_location)

# Display the first 5 rows of the DataFrame
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
#Shape of the dataframe df
print(df.shape)
# Out:
# (569, 32)

# %%
#Columns/Features present in df
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
# Convert 'diagnosis' to integers (1 for 'M' and 0 for 'B')
df['diagnosis'] = df['diagnosis'].apply(lambda x: 1 if x == 'M' else 0)

# Set 'id' column as the index
df = df.set_index('id')

# Display the first 5 rows of the DataFrame
df.head(5)
# Out:
#           diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302            1        17.99         10.38          122.80     1001.0
# 842517            1        20.57         17.77          132.90     1326.0
# 84300903          1        19.69         21.25          130.00     1203.0
# 84348301          1        11.42         20.38           77.58      386.1
# 84358402          1        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# 842302                0.14710         0.2419  ...         25.38
# 842517                0.07017         0.1812  ...         24.99
# 84300903              0.12790         0.2069  ...         23.57
# 84348301              0.10520         0.2597  ...         14.91
# 84358402              0.10430         0.1809  ...         22.54
#
#           texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# id
# 842302            17.33           184.60      2019.0            0.1622
# 842517            23.41           158.80      1956.0            0.1238
# 84300903          25.53           152.50      1709.0            0.1444
# 84348301          26.50            98.87       567.7            0.2098
# 84358402          16.67           152.20      1575.0            0.1374
#
#           compactness_worst  concavity_worst  concave points_worst  \
# id
# 842302               0.6656           0.7119                0.2654
# 842517               0.1866           0.2416                0.1860
# 84300903             0.4245           0.4504                0.2430
# 84348301             0.8663           0.6869                0.2575
# 84358402             0.2050           0.4000                0.1625
#
#           symmetry_worst  fractal_dimension_worst
# id
# 842302            0.4601                  0.11890
# 842517            0.2750                  0.08902
# 84300903          0.3613                  0.08758
# 84348301          0.6638                  0.17300
# 84358402          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
#Concise Summary of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1)
# memory usage: 142.2 KB

# %%
# Number of Benign and Malignant tumor patients
benign, malignant = df['diagnosis'].value_counts()
print("Number of Benign patients:", benign)
print("Number of Malignant patients:", malignant)
# Out:
# Number of Benign patients: 357
# Number of Malignant patients: 212

# %% [markdown]
# # Splitting data into Train and Test sets:
#
# The process data is now split into train and test sets. For this project, 80% of the data is allocated for training and 20% for testing the model.

# %%
# Splitting the dataset into train and test sets
cancer_data = df.values
num_train = int(cancer_data.shape[0] * 0.80)  # 80% of the data should be training
X_train = cancer_data[:num_train, 1:32]  # Feature Vector for Training
y_train = cancer_data[:num_train, 0]  # Label or Target Vector for Training
X_test = cancer_data[num_train:, 1:32]  # Feature Vector for Testing
y_test = cancer_data[num_train:, 0]  # Label or Target Vector for Testing

print('Length of Train set:', len(X_train))
print('Length of Test set:', len(y_test))
print('First training sample:\n', X_train[0])
print('First Label/Target sample:', y_train[0])
# Out:
# Length of Train set: 455
# Length of Test set: 114
# First training sample:
#  [1.799e+01 1.038e+01 1.228e+02 1.001e+03 1.184e-01 2.776e-01 3.001e-01
#  1.471e-01 2.419e-01 7.871e-02 1.095e+00 9.053e-01 8.589e+00 1.534e+02
#  6.399e-03 4.904e-02 5.373e-02 1.587e-02 3.003e-02 6.193e-03 2.538e+01
#  1.733e+01 1.846e+02 2.019e+03 1.622e-01 6.656e-01 7.119e-01 2.654e-01
#  4.601e-01 1.189e-01]
# First Label/Target sample: 1.0

# %% [markdown]
# # Create an output path for the trained models in s3:
#
# This step would be creating an output path in s3 for trained models to reside.

# %%
s3_prefix = 'cancer-detection'
output_path = 's3://{}/{}'.format(bucket, s3_prefix)

# %% [markdown]
# # Creating an Object of LinearLearner:
#
# Next important step would be to create an Object with LinearLeaner class to train the the model with training data.
# A high-level estimator class Linear Learner is used to initiate training job and inference endpoint.
# One advantage of using this over Python SDK’s generic Estimator class is that we need not specify the location of
# algorithm container we wish to use for training the model.

# %%
import sagemaker

session = sagemaker.Session()
linear = sagemaker.LinearLearner(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.m4.xlarge',  # Use regular single quotes ('') here
    predictor_type='binary_classifier',
    output_path=output_path,
    sagemaker_session=session,
    epochs=20
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# # Wrap data into RecordSet objects:
#
# This step is all about converting data which is in numpy array format to record set format which is done by using
# record_set() function

# %%
# Convert numpy arrays into RecordSet
training_recordset = linear.record_set(train=X_train.astype('float32'), labels=y_train.astype('float32'))

# %% [markdown]
# # Fit the model to the training data:
#
# This step does the fitting of model with the trained data form the previous step.

# %%
linear.fit(training_recordset)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-09-01-08-36-45-587
# 2023-09-01 08:36:45 Starting - Starting the training job...
# 2023-09-01 08:37:10 Starting - Preparing the instances for training.........
# 2023-09-01 08:38:42 Downloading - Downloading input data...
# 2023-09-01 08:39:12 Training - Downloading the training image.........
# 2023-09-01 08:40:23 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/01/2023 08:40:39 INFO 140046298789696] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/01/2023 08:40:39 INFO 140046298789696] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '20', 'feature_dim': '30', 'mini_batch_size': '455', 'predictor_type': 'binary_classifier'}
# [09/01/2023 08:40:39 INFO 140046298789696] Final configuration: {'mini_batch_size': '455', 'epochs': '20', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/01/2023 08:40:42 WARNING 140046298789696] Loggers have already been setup.
# [09/01/2023 08:40:42 INFO 140046298789696] Final configuration: {'mini_batch_size': '455', 'epochs': '20', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/01/2023 08:40:43 WARNING 140046298789696] Loggers have already been setup.
# Process 7 is a worker.
# [09/01/2023 08:40:43 INFO 140046298789696] Using default worker.
# [09/01/2023 08:40:43 INFO 140046298789696] Checkpoint loading and saving are disabled.
# [2023-09-01 08:40:43.139] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes": 76440}
# [09/01/2023 08:40:43 INFO 140046298789696] Create Store: local
# [2023-09-01 08:40:43.153] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 13, "num_examples": 1, "num_bytes": 76440}
# [09/01/2023 08:40:43 INFO 140046298789696] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f5e8184d390>
# [09/01/2023 08:40:43 INFO 140046298789696] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [3.4972811e+00 4.0782666e+00 2.4095407e+01 3.4740530e+02 1.3686808e-02
#  5.3808130e-02 8.0658793e-02 3.9123639e-02 2.8090565e-02 6.9889664e-03
#  2.7019033e-01 5.3117156e-01 1.9740525e+00 4.2035542e+01 2.9872940e-03
#  1.8612141e-02 3.1974602e-02 6.2293871e-03 8.7045571e-03 2.7667778e-03
#  4.8299079e+00 6.0416675e+00 3.3444248e+01 5.6458331e+02 2.2992259e-02
#  1.6230838e-01 2.1182451e-01 6.6776372e-02 6.4415343e-02 1.8402873e-02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [1.42353477e+01 1.89894943e+01 9.27036285e+01 6.63945740e+02
#  9.64635164e-02 1.04998179e-01 9.13799256e-02 5.03508374e-02
#  1.82319999e-01 6.26400188e-02 4.11377132e-01 1.20115983e+00
#  2.90352249e+00 4.09164047e+01 6.99292077e-03 2.58164126e-02
#  3.24603692e-02 1.19302003e-02 2.09423248e-02 3.80793912e-03
#  1.64500446e+01 2.54110336e+01 1.08434639e+02 8.98830078e+02
#  1.32548422e-01 2.58022338e-01 2.78478295e-01 1.17213935e-01
#  2.94084847e-01 8.40151235e-02]
# <NDArray 30 @cpu(0)>}
# [09/01/2023 08:40:43 INFO 140046298789696] nvidia-smi: took 0.032 seconds to run.
# [09/01/2023 08:40:43 INFO 140046298789696] nvidia-smi identified 0 GPUs.
# [09/01/2023 08:40:43 INFO 140046298789696] Number of GPUs being used: 0
# #metrics {"StartTime": 1693557643.2666326, "EndTime": 1693557643.266669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 910.0, "count": 1, "min": 910, "max": 910}, "Total Batches Seen": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2023-09-01 08:40:43.319] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 51, "num_examples": 1, "num_bytes": 76440}
# #metrics {"StartTime": 1693557643.3191764, "EndTime": 1693557643.3192573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.59873046875, "count": 1, "min": 0.59873046875, "max": 0.59873046875}}}
# #metrics {"StartTime": 1693557643.3193357, "EndTime": 1693557643.319351, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6736263065547734, "count": 1, "min": 0.6736263065547734, "max": 0.6736263065547734}}}
# #metrics {"StartTime": 1693557643.3193965, "EndTime": 1693557643.3194082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7597958072201236, "count": 1, "min": 0.7597958072201236, "max": 0.7597958072201236}}}
# #metrics {"StartTime": 1693557643.319451, "EndTime": 1693557643.319462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6883417485834478, "count": 1, "min": 0.6883417485834478, "max": 0.6883417485834478}}}
# #metrics {"StartTime": 1693557643.319504, "EndTime": 1693557643.3195152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6656296950120192, "count": 1, "min": 0.6656296950120192, "max": 0.6656296950120192}}}
# #metrics {"StartTime": 1693557643.3195574, "EndTime": 1693557643.3195682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8286150921832074, "count": 1, "min": 0.8286150921832074, "max": 0.8286150921832074}}}
# #metrics {"StartTime": 1693557643.3196049, "EndTime": 1693557643.3196151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6265482808207418, "count": 1, "min": 0.6265482808207418, "max": 0.6265482808207418}}}
# #metrics {"StartTime": 1693557643.3196528, "EndTime": 1693557643.3196633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6049041412688874, "count": 1, "min": 0.6049041412688874, "max": 0.6049041412688874}}}
# #metrics {"StartTime": 1693557643.3197, "EndTime": 1693557643.3197105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.683889401614011, "count": 1, "min": 0.683889401614011, "max": 0.683889401614011}}}
# #metrics {"StartTime": 1693557643.3209894, "EndTime": 1693557643.3210273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7580127757984203, "count": 1, "min": 0.7580127757984203, "max": 0.7580127757984203}}}
# #metrics {"StartTime": 1693557643.3210902, "EndTime": 1693557643.3211076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6768904130537431, "count": 1, "min": 0.6768904130537431, "max": 0.6768904130537431}}}
# #metrics {"StartTime": 1693557643.3211594, "EndTime": 1693557643.3211753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7422481997982486, "count": 1, "min": 0.7422481997982486, "max": 0.7422481997982486}}}
# #metrics {"StartTime": 1693557643.3212254, "EndTime": 1693557643.3212419, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6489357078468406, "count": 1, "min": 0.6489357078468406, "max": 0.6489357078468406}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.59873046875
# [09/01/2023 08:40:43 INFO 140046298789696] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.5780768425910028
# [09/01/2023 08:40:43 INFO 140046298789696] Epoch 0: Loss improved. Updating best model
# [09/01/2023 08:40:43 INFO 140046298789696] Saving model for epoch: 0
# [09/01/2023 08:40:43 INFO 140046298789696] Saved checkpoint to "/tmp/tmpg21oydez/mx-mod-0000.params"
# [09/01/2023 08:40:43 INFO 140046298789696] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1693557643.266971, "EndTime": 1693557643.3318436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1365.0, "count": 1, "min": 1365, "max": 1365}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #throughput_metric: host=algo-1, train throughput=6997.0167115191425 records/second
# [2023-09-01 08:40:43.369] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 36, "num_examples": 1, "num_bytes": 76440}
# #metrics {"StartTime": 1693557643.3691776, "EndTime": 1693557643.3692555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5656412313272665, "count": 1, "min": 0.5656412313272665, "max": 0.5656412313272665}}}
# #metrics {"StartTime": 1693557643.3693953, "EndTime": 1693557643.369419, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6355718256353022, "count": 1, "min": 0.6355718256353022, "max": 0.6355718256353022}}}
# #metrics {"StartTime": 1693557643.3695319, "EndTime": 1693557643.3695533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7184471046531593, "count": 1, "min": 0.7184471046531593, "max": 0.7184471046531593}}}
# #metrics {"StartTime": 1693557643.3696501, "EndTime": 1693557643.369668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.650867906507555, "count": 1, "min": 0.650867906507555, "max": 0.650867906507555}}}
# #metrics {"StartTime": 1693557643.3697674, "EndTime": 1693557643.3697846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.32430181817694026, "count": 1, "min": 0.32430181817694026, "max": 0.32430181817694026}}}
# #metrics {"StartTime": 1693557643.3698761, "EndTime": 1693557643.3698926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3798953213534512, "count": 1, "min": 0.3798953213534512, "max": 0.3798953213534512}}}
# #metrics {"StartTime": 1693557643.3699853, "EndTime": 1693557643.3700037, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.2946086841625172, "count": 1, "min": 0.2946086841625172, "max": 0.2946086841625172}}}
# #metrics {"StartTime": 1693557643.370109, "EndTime": 1693557643.3701262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5816645695612981, "count": 1, "min": 0.5816645695612981, "max": 0.5816645695612981}}}
# #metrics {"StartTime": 1693557643.37134, "EndTime": 1693557643.3713539, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6722642835679945, "count": 1, "min": 0.6722642835679945, "max": 0.6722642835679945}}}
# #metrics {"StartTime": 1693557643.3713956, "EndTime": 1693557643.3714085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6042837289663462, "count": 1, "min": 0.6042837289663462, "max": 0.6042837289663462}}}
# #metrics {"StartTime": 1693557643.3714557, "EndTime": 1693557643.37147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6252790849287432, "count": 1, "min": 0.6252790849287432, "max": 0.6252790849287432}}}
# #metrics {"StartTime": 1693557643.3715272, "EndTime": 1693557643.371542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6366669036529876, "count": 1, "min": 0.6366669036529876, "max": 0.6366669036529876}}}
# #metrics {"StartTime": 1693557643.371589, "EndTime": 1693557643.3716037, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.8317068917410714, "count": 1, "min": 0.8317068917410714, "max": 0.8317068917410714}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.5656412313272665
# [09/01/2023 08:40:43 INFO 140046298789696] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.2835199712396978
# [09/01/2023 08:40:43 INFO 140046298789696] Epoch 1: Loss improved. Updating best model
# [09/01/2023 08:40:43 INFO 140046298789696] Saving model for epoch: 1
# [09/01/2023 08:40:43 INFO 140046298789696] Saved checkpoint to "/tmp/tmp7vd5q7yk/mx-mod-0000.params"
# [09/01/2023 08:40:43 INFO 140046298789696] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1693557643.332191, "EndTime": 1693557643.3847353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1820.0, "count": 1, "min": 1820, "max": 1820}, "Total Batches Seen": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #throughput_metric: host=algo-1, train throughput=8631.777503380961 records/second
# [2023-09-01 08:40:43.425] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 40, "num_examples": 1, "num_bytes": 76440}
# #metrics {"StartTime": 1693557643.42567, "EndTime": 1693557643.425796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.53507080078125, "count": 1, "min": 0.53507080078125, "max": 0.53507080078125}}}
# #metrics {"StartTime": 1693557643.4258816, "EndTime": 1693557643.4259028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.600368424300309, "count": 1, "min": 0.600368424300309, "max": 0.600368424300309}}}
# #metrics {"StartTime": 1693557643.4259791, "EndTime": 1693557643.4259992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.679751218020261, "count": 1, "min": 0.679751218020261, "max": 0.679751218020261}}}
# #metrics {"StartTime": 1693557643.4260588, "EndTime": 1693557643.42607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6159304440676511, "count": 1, "min": 0.6159304440676511, "max": 0.6159304440676511}}}
# #metrics {"StartTime": 1693557643.4261076, "EndTime": 1693557643.426122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.22182754684280565, "count": 1, "min": 0.22182754684280565, "max": 0.22182754684280565}}}
# #metrics {"StartTime": 1693557643.426186, "EndTime": 1693557643.4262044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.24396617176768545, "count": 1, "min": 0.24396617176768545, "max": 0.24396617176768545}}}
# #metrics {"StartTime": 1693557643.4262638, "EndTime": 1693557643.4262822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.20191026624742445, "count": 1, "min": 0.20191026624742445, "max": 0.20191026624742445}}}
# #metrics {"StartTime": 1693557643.4263368, "EndTime": 1693557643.4263535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.19285553313873627, "count": 1, "min": 0.19285553313873627, "max": 0.19285553313873627}}}
# #metrics {"StartTime": 1693557643.4264674, "EndTime": 1693557643.42649, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6920115041208791, "count": 1, "min": 0.6920115041208791, "max": 0.6920115041208791}}}
# #metrics {"StartTime": 1693557643.4265506, "EndTime": 1693557643.4265673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6068958324390453, "count": 1, "min": 0.6068958324390453, "max": 0.6068958324390453}}}
# #metrics {"StartTime": 1693557643.4266212, "EndTime": 1693557643.4266384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.603384768307864, "count": 1, "min": 0.603384768307864, "max": 0.603384768307864}}}
# #metrics {"StartTime": 1693557643.4266927, "EndTime": 1693557643.4267097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6261791187328297, "count": 1, "min": 0.6261791187328297, "max": 0.6261791187328297}}}
# #metrics {"StartTime": 1693557643.4267542, "EndTime": 1693557643.4267695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.22904270717075892, "count": 1, "min": 0.22904270717075892, "max": 0.22904270717075892}}}
# #metrics {"StartTime": 1693557643.4268188, "EndTime": 1693557643.4268346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.208296388060182, "count": 1, "min": 0.208296388060182, "max": 0.208296388060182}}}
# #metrics {"StartTime": 1693557643.426885, "EndTime": 1693557643.4269004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.2249827625987294, "count": 1, "min": 0.2249827625987294, "max": 0.2249827625987294}}}
# #metrics {"StartTime": 1693557643.4269457, "EndTime": 1693557643.4269583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.2291812267932263, "count": 1, "min": 0.2291812267932263, "max": 0.2291812267932263}}}
# #metrics {"StartTime": 1693557643.4270177, "EndTime": 1693557643.4270341, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5178274636740213, "count": 1, "min": 0.5178274636740213, "max": 0.5178274636740213}}}
# #metrics {"StartTime": 1693557643.427095, "EndTime": 1693557643.4271133, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6442706097613324, "count": 1, "min": 0.6442706097613324, "max": 0.6442706097613324}}}
# #metrics {"StartTime": 1693557643.4271708, "EndTime": 1693557643.4271882, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.613669929923592, "count": 1, "min": 0.613669929923592, "max": 0.613669929923592}}}
# #metrics {"StartTime": 1693557643.42724, "EndTime": 1693557643.427257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6520390437199519, "count": 1, "min": 0.6520390437199519, "max": 0.6520390437199519}}}
# #metrics {"StartTime": 1693557643.4273195, "EndTime": 1693557643.4273372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.23237998878562843, "count": 1, "min": 0.23237998878562843, "max": 0.23237998878562843}}}
# #metrics {"StartTime": 1693557643.4273996, "EndTime": 1693557643.427416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.22322437999012706, "count": 1, "min": 0.22322437999012706, "max": 0.22322437999012706}}}
# #metrics {"StartTime": 1693557643.4274678, "EndTime": 1693557643.4274828, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.22979878855275584, "count": 1, "min": 0.22979878855275584, "max": 0.22979878855275584}}}
# #metrics {"StartTime": 1693557643.427515, "EndTime": 1693557643.4275234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.22614893651270604, "count": 1, "min": 0.22614893651270604, "max": 0.22614893651270604}}}
# #metrics {"StartTime": 1693557643.4275482, "EndTime": 1693557643.4275556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7077911712311127, "count": 1, "min": 0.7077911712311127, "max": 0.7077911712311127}}}
# #metrics {"StartTime": 1693557643.4275997, "EndTime": 1693557643.4276135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7396503155048076, "count": 1, "min": 0.7396503155048076, "max": 0.7396503155048076}}}
# #metrics {"StartTime": 1693557643.4276545, "EndTime": 1693557643.4276695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5862495841560783, "count": 1, "min": 0.5862495841560783, "max": 0.5862495841560783}}}
# #metrics {"StartTime": 1693557643.4277196, "EndTime": 1693557643.4277353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6628597720638736, "count": 1, "min": 0.6628597720638736, "max": 0.6628597720638736}}}
# #metrics {"StartTime": 1693557643.4277894, "EndTime": 1693557643.4278054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6052735716432005, "count": 1, "min": 0.6052735716432005, "max": 0.6052735716432005}}}
# #metrics {"StartTime": 1693557643.427853, "EndTime": 1693557643.4278688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6638184264466003, "count": 1, "min": 0.6638184264466003, "max": 0.6638184264466003}}}
# #metrics {"StartTime": 1693557643.427914, "EndTime": 1693557643.4279294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.619501470209478, "count": 1, "min": 0.619501470209478, "max": 0.619501470209478}}}
# #metrics {"StartTime": 1693557643.4279883, "EndTime": 1693557643.4280045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7072462815504807, "count": 1, "min": 0.7072462815504807, "max": 0.7072462815504807}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.53507080078125
# [09/01/2023 08:40:43 INFO 140046298789696] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.19285553313873627
# [09/01/2023 08:40:43 INFO 140046298789696] Epoch 2: Loss improved. Updating best model
# [09/01/2023 08:40:43 INFO 140046298789696] Saving model for epoch: 2
# [09/01/2023 08:40:43 INFO 140046298789696] Saved checkpoint to "/tmp/tmpajfsz0eo/mx-mod-0000.params"
# [09/01/2023 08:40:43 INFO 140046298789696] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1693557643.385086, "EndTime": 1693557643.4361508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2275.0, "count": 1, "min": 2275, "max": 2275}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [09/01/2023 08:40:43 INFO 140046298789696] #throughput_metric: host=algo-1, train throughput=8886.816611252363 records/second
# [2023-09-01 08:40:43.466] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 29, "num_examples": 1, "num_bytes": 76440}
# #metrics {"StartTime": 1693557643.4665744, "EndTime": 1693557643.466643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.506962635752919, "count": 1, "min": 0.506962635752919, "max": 0.506962635752919}}}
# #metrics {"StartTime": 1693557643.4667306, "EndTime": 1693557643.466753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5679439335078984, "count": 1, "min": 0.5679439335078984, "max": 0.5679439335078984}}}
# ...
# #metrics {"StartTime": 1693557644.3284209, "EndTime": 1693557644.3284428, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.30570584810697116, "count": 1, "min": 0.30570584810697116, "max": 0.30570584810697116}}}
# #metrics {"StartTime": 1693557644.328498, "EndTime": 1693557644.3285155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0671151381272536, "count": 1, "min": 0.0671151381272536, "max": 0.0671151381272536}}}
# #metrics {"StartTime": 1693557644.3286116, "EndTime": 1693557644.3286328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.06866525503305289, "count": 1, "min": 0.06866525503305289, "max": 0.06866525503305289}}}
# #metrics {"StartTime": 1693557644.3287303, "EndTime": 1693557644.3287518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6501075828468407, "count": 1, "min": 0.6501075828468407, "max": 0.6501075828468407}}}
# #metrics {"StartTime": 1693557644.3305745, "EndTime": 1693557644.33059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6397042410714285, "count": 1, "min": 0.6397042410714285, "max": 0.6397042410714285}}}
# #metrics {"StartTime": 1693557644.330643, "EndTime": 1693557644.3306592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6805045662345467, "count": 1, "min": 0.6805045662345467, "max": 0.6805045662345467}}}
# #metrics {"StartTime": 1693557644.3307128, "EndTime": 1693557644.3307302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6638838212568682, "count": 1, "min": 0.6638838212568682, "max": 0.6638838212568682}}}
# #metrics {"StartTime": 1693557644.3308477, "EndTime": 1693557644.3308687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6225944099845467, "count": 1, "min": 0.6225944099845467, "max": 0.6225944099845467}}}
# #metrics {"StartTime": 1693557644.3309395, "EndTime": 1693557644.3309581, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6314115084134615, "count": 1, "min": 0.6314115084134615, "max": 0.6314115084134615}}}
# #metrics {"StartTime": 1693557644.3310244, "EndTime": 1693557644.3310435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6392633794428229, "count": 1, "min": 0.6392633794428229, "max": 0.6392633794428229}}}
# #metrics {"StartTime": 1693557644.3310995, "EndTime": 1693557644.3311179, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6892690805288462, "count": 1, "min": 0.6892690805288462, "max": 0.6892690805288462}}}
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, epoch=19, train binary_classification_cross_entropy_objective <loss>=0.275243419605297
# [09/01/2023 08:40:44 INFO 140046298789696] #early_stopping_criteria_metric: host=algo-1, epoch=19, criteria=binary_classification_cross_entropy_objective, value=0.0670403574849223
# [09/01/2023 08:40:44 INFO 140046298789696] Epoch 19: Loss improved. Updating best model
# [09/01/2023 08:40:44 INFO 140046298789696] Saving model for epoch: 19
# [09/01/2023 08:40:44 INFO 140046298789696] Saved checkpoint to "/tmp/tmp68fank_a/mx-mod-0000.params"
# [09/01/2023 08:40:44 INFO 140046298789696] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1693557644.2879252, "EndTime": 1693557644.3412914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10010.0, "count": 1, "min": 10010, "max": 10010}, "Total Batches Seen": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [09/01/2023 08:40:44 INFO 140046298789696] #throughput_metric: host=algo-1, train throughput=8493.025549280606 records/second
# [09/01/2023 08:40:44 WARNING 140046298789696] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/01/2023 08:40:44 WARNING 140046298789696] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2023-09-01 08:40:44.343] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 44, "duration": 1, "num_examples": 1, "num_bytes": 76440}
# [2023-09-01 08:40:44.470] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 47, "duration": 121, "num_examples": 1, "num_bytes": 76440}
# [2023-09-01 08:40:44.490] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 49, "duration": 5, "num_examples": 1, "num_bytes": 76440}
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.06645357739794386)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('binary_classification_accuracy', 0.9758241758241758)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('binary_f_1.000', 0.9700272479564033)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('precision', 0.9834254143646409)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('recall', 0.956989247311828)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('roc_auc_score', 0.9966822560658752)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [09/01/2023 08:40:44 INFO 140046298789696] #train_score (algo-1) : ('binary_log_loss', 0.5524983100875472)
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.06645357739794386
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9758241758241758
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.9700272479564033
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train precision <score>=0.9834254143646409
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train recall <score>=0.956989247311828
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9966822560658752
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [09/01/2023 08:40:44 INFO 140046298789696] #quality_metric: host=algo-1, train binary_log_loss <score>=0.5524983100875472
# [09/01/2023 08:40:44 INFO 140046298789696] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [09/01/2023 08:40:44 INFO 140046298789696] Saved checkpoint to "/tmp/tmpoep4xa7g/mx-mod-0000.params"
# [09/01/2023 08:40:44 INFO 140046298789696] Test data is not provided.
# #metrics {"StartTime": 1693557643.1214213, "EndTime": 1693557644.512393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 143.4926986694336, "count": 1, "min": 143.4926986694336, "max": 143.4926986694336}, "epochs": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "check_early_stopping.time": {"sum": 20.058631896972656, "count": 20, "min": 0.21409988403320312, "max": 1.4252662658691406}, "update.time": {"sum": 999.6359348297119, "count": 20, "min": 38.18464279174805, "max": 61.14602088928223}, "finalize.time": {"sum": 161.27967834472656, "count": 1, "min": 161.27967834472656, "max": 161.27967834472656}, "setuptime": {"sum": 2.601146697998047, "count": 1, "min": 2.601146697998047, "max": 2.601146697998047}, "totaltime": {"sum": 1514.4166946411133, "count": 1, "min": 1514.4166946411133, "max": 1514.4166946411133}}}
#
# 2023-09-01 08:41:05 Uploading - Uploading generated training model
# 2023-09-01 08:41:05 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142

# %% [markdown]
# # Model Deployment to the endpoint:
#
# Now that we have a trained model, we want to make predictions and evaluate model performance on our test set. For that we’ll need to deploy a model hosting endpoint to accept inference requests using the estimator API. This is done by the following instructions

# %%
linear_predictor = linear.deploy(
    initial_instance_count=1,
    instance_type='ml.t2.medium'  # Use regular single quotes ('') here
)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: linear-learner-2023-09-01-08-51-27-653
# INFO:sagemaker:Creating endpoint-config with name linear-learner-2023-09-01-08-51-27-653
# INFO:sagemaker:Creating endpoint with name linear-learner-2023-09-01-08-51-27-653
# ------------------!

# %% [markdown]
# # Testing with one sample test data:
#
# Next after model has been deployed to an endpoint, the users can test the trained model with the data that has previously
# not seen by the training process. Here, we will be testing with one single sample test data.

# %%
sample = X_test.astype('float32')
print(linear_predictor.predict(sample[0]))
# Out:
# [label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.616036654
#     }
#   }
# }
# label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 1
#     }
#   }
# }
# ]

# %% [markdown]
# # Classification Metrics:
#
# Now after model has been tested with one single sample test data we must evaluate the model performance with complete test data.
# Here we write a function to evaluate the metrics which takes test features, deployment object,test labels, batch size as inputs.
# The output of the function is the classification metrics such as precision, recall and accuracy.
# The entire test data is divided into batches..

# %%
#Function to evaluate the deployed model with the entire test set
import numpy as np
import pandas as pd

def evaluate(predictor, test_features, test_labels, test_batch_size=10, verbose=True):
    input_batches = [predictor.predict(batch) for batch in np.array_split(test_features.astype('float32'), test_batch_size)]
    
    predicted_labels = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) for batch in input_batches])

    true_pos = np.logical_and(test_labels, predicted_labels).sum()
    false_pos = np.logical_and(1 - test_labels, predicted_labels).sum()
    true_neg = np.logical_and(1 - test_labels, 1 - predicted_labels).sum()
    false_neg = np.logical_and(test_labels, 1 - predicted_labels).sum()

    recall = true_pos / (true_pos + false_neg)
    precision = true_pos / (true_pos + false_pos)
    accuracy = (true_pos + true_neg) / (true_pos + false_pos + true_neg + false_neg)

    if verbose:
        print(pd.crosstab(test_labels, predicted_labels, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()

    return {
        'tp': true_pos,
        'tn': true_neg,
        'fp': false_pos,
        'fn': false_neg,
        'precision': precision,
        'recall': recall,
        'accuracy': accuracy
    }

# %% [markdown]
# # Evaluating the trained model with test data:
# This step is about evaluating the model by calling the evaluate() function on X_test and y_test data.

# %%
#Model evaluation with test data
evaluate(linear_predictor, X_test.astype(float), y_test.astype(float))
# Out:
# prediction (col)  0.0  1.0
# actual (row)
# 0.0                86    2
# 1.0                 1   25
# Recall:     0.962
# Precision:  0.926
# Accuracy:   0.974
# {'tp': 25,
#  'tn': 86,
#  'fp': 2,
#  'fn': 1,
#  'precision': 0.9259259259259259,
#  'recall': 0.9615384615384616,
#  'accuracy': 0.9736842105263158}

# %%
#Delete the endpoint
session.delete_endpoint(linear_predictor.endpoint)

# %% [markdown]
# # Conclusion:
#
# The model is built and trained with AWS Linear-Learner classification algorithm for predicting the breast cancer.
# The accuracy of the classifier is 97.36% with a precision and recall of 92.59% and 96.15% respectively.
# It is observed that accuracy is good with Linear-Learner, which uses a linear model to map input to the outputs.
# The accuracy of predictions can be further improved by employing complex nonlinear AWS SageMaker algorithms.
